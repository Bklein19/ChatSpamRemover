# %% [markdown]
# # Data Layout
#
# Collection of chat log of 2,162 Twitch streaming videos by 52 streamers. Time period of target streaming video is from 2018-04-24 to 2018-06-24.
#
# ## Description of columns follows below:
# ### body: Actual text for user chat
# ### channel_id: Channel identifier (integer)
# ### commenter_id: User identifier (integer)
# ### commenter_type: User type (character)
# ### created_at: Time of when chat was entered (ISO 8601 date and time)
# ### fragments: Chat text including parsing information of Twitch emote (JSON list)
# ### offset: Time offset between start time of video stream and the time of when chat was entered (float)
# ### updated_at: Time of when chat was edited (ISO 8601 date and time)
# ### video_id: Video identifier (integer)
#
# #### File name indicates name of Twitch stream channel.
# #### This dataset is saved as python3 pandas.DataFrame with python pickle format.
# #### import pandas as pd
# #### pd.read_pickle('Twitch_data/ICWSM19_data/ninja.pkl')
#
# courtesy of https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/VE0IVQ

# %% [markdown]
# #### Think about this:
# # What is the purpose of this? -- clean spam on the fly? recap chat? something else?
# ##### -
# ##### -
# # Todo (codewise):
# ### - Pull in data using pickle
# ### - Identify relevant chat (either selecting best chat each minute or best chats overall)
# ### - Trim out irrelevant chat

# %%
import pandas as pd
import re
#ninja_chat = pd.read_pickle('Twitch_data/ICWSM19_data/ninja.pkl')
chocobars_chat = pd.read_pickle('Twitch_data/ICWSM19_data/xchocobars.pkl')
#xqc_chat = pd.read_pickle('Twitch_data/ICWSM19_data/xqcow.pkl')
#tyler1_chat = pd.read_pickle('Twitch_data/ICWSM19_data/loltyler1.pkl')

# %%
chocobars_chat
# Out:
#                                                       body channel_id  \
# 0                                                   VoHiYo   42583390
# 1                                                hey janet   42583390
# 2        Make sure to check out Janet's newest video! Y...   42583390
# 3                                             POGGERS LIVE   42583390
# 4                                             LIVE POGGERS   42583390
# 5                                             LIVE POGGERS   42583390
# 6                                           solo squading?   42583390
# 7                                                chocoWave   42583390
# 8                                             LIVE POGGERS   42583390
# 9                                                chcooWave   42583390
# 10                                            live POGGERS   42583390
# 11                                                 POGGERS   42583390
# 12                                                 POGGERS   42583390
# 13                                                 COGGERS   42583390
# 14                                                chocoHug   42583390
# 15                                            LIVE POGGERS   42583390
# 16                                            LIVE POGGERS   42583390
# 17       chocoWave chocoH chocoWave chocoH chocoWave ch...   42583390
# 18                 chocoWave chocoWave chocoWave chocoWave   42583390
# 19                                               chocoWave   42583390
# 20                                                 POGGERS   42583390
# 21                 chocoWave chocoWave chocoWave chocoWave   42583390
# 22                                                 POGGERS   42583390
# 23                                                 POGGERS   42583390
# 24                                                 POGGERS   42583390
# 25                                            LIVE POGGERS   42583390
# 26                                            LIVE POGGERS   42583390
# 27                                        chocoWave chocoH   42583390
# 28                               @xChocoBars chocoWave HI~   42583390
# 29                                            LIVE POGGERS   42583390
# ...                                                    ...        ...
# 1097545                  chocoWave chocoH chocoWave chocoH   42583390
# 1097546                                   chocoWave chocoH   42583390
# 1097547  chocoWave chocoWave chocoWave chocoH chocoWave...   42583390
# 1097548                   @Marinht wait what do u mean LOL   42583390
# 1097549                                      Stay fresh af   42583390
# 1097550                                   chocoWave chocoH   42583390
# 1097551                    Bye mom toastyG toastyG toastyG   42583390
# 1097552                                            POGGERS   42583390
# 1097553                  chocoWave chocoH chocoWave chocoH   42583390
# 1097554                                            POGGERS   42583390
# 1097555                                       TLOU POGGERS   42583390
# 1097556                                          chocoWave   42583390
# 1097557                                            POGGERS   42583390
# 1097558                                          chocoWave   42583390
# 1097559  XELL IS DANCING IF ANYONE WANTS TO WATCH toast...   42583390
# 1097560                             TLOU WITH ECHO POGGERS   42583390
# 1097561                                chocoWave chocoWave   42583390
# 1097562  chocoWave chocoWave chocoH chocoWave chocoH ch...   42583390
# 1097563                                          chocoWave   42583390
# 1097564  chocoWave chocoH chocoWave chocoH chocoWave ch...   42583390
# 1097565                                            POGGERS   42583390
# 1097566                                   chocoWave chocoH   42583390
# 1097567                                              Byeee   42583390
# 1097568                                 chocoWave chocoHug   42583390
# 1097569                                            POGGERS   42583390
# 1097570                                             NomNom   42583390
# 1097571                   ThumpFooty ThumpFooty ThumpFooty   42583390
# 1097572                                            POGGERS   42583390
# 1097573                         @sirgee562 STREAM fedHYPER   42583390
# 1097574                                       TEE LOU HYPE   42583390
#
#         commenter_id commenter_type                created_at  \
# 0           21074622           user  2018-06-15T22:20:35.628Z
# 1          128772138           user  2018-06-15T22:20:35.698Z
# 2            1564983           user  2018-06-15T22:20:36.003Z
# 3           30560738           user  2018-06-15T22:20:36.682Z
# 4           30560738           user  2018-06-15T22:20:38.942Z
# 5           36677871           user  2018-06-15T22:20:39.285Z
# 6           58534036           user  2018-06-15T22:20:39.858Z
# 7           38404293           user  2018-06-15T22:20:40.119Z
# 8           44498776           user   2018-06-15T22:20:40.14Z
# 9           94504639           user  2018-06-15T22:20:41.251Z
# 10         136425910           user  2018-06-15T22:20:42.027Z
# 11         118535772           user  2018-06-15T22:20:43.183Z
# 12         196599028           user  2018-06-15T22:20:43.458Z
# 13          94504639           user   2018-06-15T22:20:43.65Z
# 14          48249114           user  2018-06-15T22:20:43.671Z
# 15          59143692           user  2018-06-15T22:20:43.742Z
# 16         136628769           user  2018-06-15T22:20:44.952Z
# 17          21614495           user  2018-06-15T22:20:45.241Z
# 18          77695226           user  2018-06-15T22:20:45.263Z
# 19          48249114           user  2018-06-15T22:20:45.267Z
# 20         136446295           user  2018-06-15T22:20:45.295Z
# 21          86068629           user  2018-06-15T22:20:45.627Z
# 22          24345416           user  2018-06-15T22:20:45.735Z
# 23         195433074           user  2018-06-15T22:20:46.025Z
# 24          47852790           user  2018-06-15T22:20:46.261Z
# 25          53383098           user  2018-06-15T22:20:46.933Z
# 26          50192778           user  2018-06-15T22:20:47.348Z
# 27          94504639           user  2018-06-15T22:20:48.288Z
# 28          31310249           user  2018-06-15T22:20:48.398Z
# 29          47852790           user  2018-06-15T22:20:49.014Z
# ...              ...            ...                       ...
# 1097545     47984072           user  2018-06-15T02:58:09.545Z
# 1097546    169913415           user  2018-06-15T02:58:10.249Z
# 1097547     86068629           user  2018-06-15T02:58:10.272Z
# 1097548     53383098           user  2018-06-15T02:58:10.375Z
# 1097549    152255077           user  2018-06-15T02:58:10.771Z
# 1097550     73000566           user  2018-06-15T02:58:11.264Z
# 1097551     66563758           user   2018-06-15T02:58:11.35Z
# 1097552    168649584           user  2018-06-15T02:58:11.453Z
# 1097553    118535772           user  2018-06-15T02:58:13.023Z
# 1097554    142832370           user  2018-06-15T02:58:13.166Z
# 1097555     51729798           user  2018-06-15T02:58:13.608Z
# 1097556     99572526           user  2018-06-15T02:58:14.006Z
# 1097557     30560738           user  2018-06-15T02:58:14.107Z
# 1097558    136425910           user  2018-06-15T02:58:14.528Z
# 1097559    162576718           user  2018-06-15T02:58:14.528Z
# 1097560     76559309           user  2018-06-15T02:58:14.935Z
# 1097561     32378116           user  2018-06-15T02:58:14.974Z
# 1097562     86068629           user  2018-06-15T02:58:15.194Z
# 1097563    124059744           user  2018-06-15T02:58:15.347Z
# 1097564     43771783           user  2018-06-15T02:58:15.362Z
# 1097565    123308049           user  2018-06-15T02:58:15.371Z
# 1097566    158454595           user   2018-06-15T02:58:16.55Z
# 1097567    203187088           user  2018-06-15T02:58:16.767Z
# 1097568     95796912           user  2018-06-15T02:58:16.939Z
# 1097569    129018963           user  2018-06-15T02:58:17.075Z
# 1097570     94241168           user  2018-06-15T02:58:17.257Z
# 1097571     87836553           user  2018-06-15T02:58:17.659Z
# 1097572    109498788           user  2018-06-15T02:58:18.702Z
# 1097573     48170005           user    2018-06-15T02:58:19.1Z
# 1097574     48552774           user  2018-06-15T02:58:19.105Z
#
#                                                  fragments     offset  \
# 0                               [{'emoticon_id': '81274'}]      2.928
# 1                                  [{'text': 'hey janet'}]      2.998
# 2        [{'text': 'Make sure to check out Janet's newe...      3.303
# 3                               [{'text': 'POGGERS LIVE'}]      3.982
# 4                               [{'text': 'LIVE POGGERS'}]      6.242
# 5                               [{'text': 'LIVE POGGERS'}]      6.585
# 6                             [{'text': 'solo squading?'}]      7.158
# 7                               [{'emoticon_id': '17662'}]      7.419
# 8                               [{'text': 'LIVE POGGERS'}]      7.440
# 9                                  [{'text': 'chcooWave'}]      8.551
# 10                              [{'text': 'live POGGERS'}]      9.327
# 11                                   [{'text': 'POGGERS'}]     10.483
# 12                                   [{'text': 'POGGERS'}]     10.758
# 13                                   [{'text': 'COGGERS'}]     10.950
# 14                            [{'emoticon_id': '1094024'}]     10.971
# 15                              [{'text': 'LIVE POGGERS'}]     11.042
# 16                              [{'text': 'LIVE POGGERS'}]     12.252
# 17       [{'emoticon_id': '17662'}, {'text': ' '}, {'em...     12.541
# 18       [{'emoticon_id': '17662'}, {'text': ' '}, {'em...     12.563
# 19                              [{'emoticon_id': '17662'}]     12.567
# 20                                   [{'text': 'POGGERS'}]     12.595
# 21       [{'emoticon_id': '17662'}, {'text': ' '}, {'em...     12.927
# 22                                   [{'text': 'POGGERS'}]     13.035
# 23                                   [{'text': 'POGGERS'}]     13.325
# 24                                   [{'text': 'POGGERS'}]     13.561
# 25                              [{'text': 'LIVE POGGERS'}]     14.233
# 26                              [{'text': 'LIVE POGGERS'}]     14.648
# 27       [{'emoticon_id': '17662'}, {'text': ' '}, {'em...     15.588
# 28       [{'text': '@xChocoBars '}, {'emoticon_id': '17...     15.698
# 29                              [{'text': 'LIVE POGGERS'}]     16.314
# ...                                                    ...        ...
# 1097545  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18592.845
# 1097546  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18593.549
# 1097547  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18593.572
# 1097548     [{'text': '@Marinht wait what do u mean LOL'}]  18593.675
# 1097549                        [{'text': 'Stay fresh af'}]  18594.071
# 1097550  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18594.564
# 1097551  [{'text': 'Bye mom '}, {'emoticon_id': '984710...  18594.650
# 1097552                              [{'text': 'POGGERS'}]  18594.753
# 1097553  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18596.323
# 1097554                              [{'text': 'POGGERS'}]  18596.466
# 1097555                         [{'text': 'TLOU POGGERS'}]  18596.908
# 1097556                         [{'emoticon_id': '17662'}]  18597.306
# 1097557                              [{'text': 'POGGERS'}]  18597.407
# 1097558                         [{'emoticon_id': '17662'}]  18597.828
# 1097559  [{'text': 'XELL IS DANCING IF ANYONE WANTS TO ...  18597.828
# 1097560               [{'text': 'TLOU WITH ECHO POGGERS'}]  18598.235
# 1097561  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18598.274
# 1097562  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18598.494
# 1097563                         [{'emoticon_id': '17662'}]  18598.647
# 1097564  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18598.662
# 1097565                              [{'text': 'POGGERS'}]  18598.671
# 1097566  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18599.850
# 1097567                                [{'text': 'Byeee'}]  18600.067
# 1097568  [{'emoticon_id': '17662'}, {'text': ' '}, {'em...  18600.239
# 1097569                              [{'text': 'POGGERS'}]  18600.375
# 1097570                         [{'emoticon_id': '90075'}]  18600.557
# 1097571  [{'emoticon_id': '1077118'}, {'text': ' '}, {'...  18600.959
# 1097572                              [{'text': 'POGGERS'}]  18602.002
# 1097573  [{'text': '@sirgee562 STREAM '}, {'emoticon_id...  18602.400
# 1097574                         [{'text': 'TEE LOU HYPE'}]  18602.405
#
#                        updated_at   video_id
# 0        2018-06-15T22:20:35.628Z  273695352
# 1        2018-06-15T22:20:35.698Z  273695352
# 2        2018-06-15T22:20:36.003Z  273695352
# 3        2018-06-15T22:20:36.682Z  273695352
# 4        2018-06-15T22:20:38.942Z  273695352
# 5        2018-06-15T22:20:39.285Z  273695352
# 6        2018-06-15T22:20:39.858Z  273695352
# 7        2018-06-15T22:20:40.119Z  273695352
# 8         2018-06-15T22:20:40.14Z  273695352
# 9        2018-06-15T22:20:41.251Z  273695352
# 10       2018-06-15T22:20:42.027Z  273695352
# 11       2018-06-15T22:20:43.183Z  273695352
# 12       2018-06-15T22:20:43.458Z  273695352
# 13        2018-06-15T22:20:43.65Z  273695352
# 14       2018-06-15T22:20:43.671Z  273695352
# 15       2018-06-15T22:20:43.742Z  273695352
# 16       2018-06-15T22:20:44.952Z  273695352
# 17       2018-06-15T22:20:45.241Z  273695352
# 18       2018-06-15T22:20:45.263Z  273695352
# 19       2018-06-15T22:20:45.267Z  273695352
# 20       2018-06-15T22:20:45.295Z  273695352
# 21       2018-06-15T22:20:45.627Z  273695352
# 22       2018-06-15T22:20:45.735Z  273695352
# 23       2018-06-15T22:20:46.025Z  273695352
# 24       2018-06-15T22:20:46.261Z  273695352
# 25       2018-06-15T22:20:46.933Z  273695352
# 26       2018-06-15T22:20:47.348Z  273695352
# 27       2018-06-15T22:20:48.288Z  273695352
# 28       2018-06-15T22:20:48.398Z  273695352
# 29       2018-06-15T22:20:49.014Z  273695352
# ...                           ...        ...
# 1097545  2018-06-15T02:58:09.545Z  273313464
# 1097546  2018-06-15T02:58:10.249Z  273313464
# 1097547  2018-06-15T02:58:10.272Z  273313464
# 1097548  2018-06-15T02:58:10.375Z  273313464
# 1097549  2018-06-15T02:58:10.771Z  273313464
# 1097550  2018-06-15T02:58:11.264Z  273313464
# 1097551   2018-06-15T02:58:11.35Z  273313464
# 1097552  2018-06-15T02:58:11.453Z  273313464
# 1097553  2018-06-15T02:58:13.023Z  273313464
# 1097554  2018-06-15T02:58:13.166Z  273313464
# 1097555  2018-06-15T02:58:13.608Z  273313464
# 1097556  2018-06-15T02:58:14.006Z  273313464
# 1097557  2018-06-15T02:58:14.107Z  273313464
# 1097558  2018-06-15T02:58:14.528Z  273313464
# 1097559  2018-06-15T02:58:14.528Z  273313464
# 1097560  2018-06-15T02:58:14.935Z  273313464
# 1097561  2018-06-15T02:58:14.974Z  273313464
# 1097562  2018-06-15T02:58:15.194Z  273313464
# 1097563  2018-06-15T02:58:15.347Z  273313464
# 1097564  2018-06-15T02:58:15.362Z  273313464
# 1097565  2018-06-15T02:58:15.371Z  273313464
# 1097566   2018-06-15T02:58:16.55Z  273313464
# 1097567  2018-06-15T02:58:16.767Z  273313464
# 1097568  2018-06-15T02:58:16.939Z  273313464
# 1097569  2018-06-15T02:58:17.075Z  273313464
# 1097570  2018-06-15T02:58:17.257Z  273313464
# 1097571  2018-06-15T02:58:17.659Z  273313464
# 1097572  2018-06-15T02:58:18.702Z  273313464
# 1097573    2018-06-15T02:58:19.1Z  273313464
# 1097574  2018-06-15T02:58:19.105Z  273313464
#
# [614469 rows x 9 columns]

# %% [markdown]
# ### Identify chat as spam or not

# %%
#Returns a value between 0 and 1 where 1 indicates a high likelihood that the chat is spam
def spam_score(message):
    #print(message['body'])
    #print(message['fragments'])
    message_fragments = message['fragments']
    return min(emote_ratio(message_fragments) + caps_ratio(message_fragments), 1)

# %%
#Returns the ratio of capital to lower case letters (in text fragments only)
def caps_ratio(message_fragments):
    lowercase_count = 0
    uppercase_special_count = 0
    special_char_count = 0
    #number_count = 0
    for fragment in message_fragments:
        #A fragment is a dictionary of 1 key value pair
        for key in fragment.keys():
            if key == "text":
                uppercase_special_count += len(re.findall(r"[A-Z]", fragment["text"]))
                lowercase_count += len(re.findall(r"[a-z]", fragment["text"]))
                #number_count += len(re.findall(r"[0-9]", string))
                uppercase_special_count += len(re.findall(r"[,.!?]", fragment["text"]))
    #print(uppercase_special_count, lowercase_count)
    return (uppercase_special_count / max(1, lowercase_count + uppercase_special_count))

# %%
#Returns the ratio of emotes to fragments of text
def emote_ratio(message_fragments):
    emote_count = 0
    non_emote_count = 0
    for fragment in message_fragments:
        #A fragment is a dictionary of 1 key value pair
        for key in fragment.keys():
            if key == "emoticon_id" or fragment["text"] == "PepeHands":
                emote_count += 1
            elif key == "text" and fragment["text"] != "PepeHands":
                if fragment["text"] == " ":
                    continue
                else:
                    non_emote_count += 1
    #print(emote_count, non_emote_count)
    return (emote_count / (non_emote_count + 1)) / max(emote_count, 1)

# %% [markdown]
# # Potential Use Case 1: Identify chatters who are constantly spamming

# %%
#avg_spam_score_dict = {}
#sum_spam_score = 0
#num_messages = 0
non_spam_messages = []
spam_messages = []
i = 0
non_spam = 0
for i, (index, row) in enumerate(chocobars_chat.iterrows()):
    if spam_score(row) < 0.25:
        non_spam += 1
        non_spam_messages.append(row['body'])
        #print(row['body'])
    else:
        spam_messages.append(row['body'])
    if i > 1000:
        print(non_spam, 1000-non_spam)
        break
    #if row['commenter_id'] == "50192778":
    #    print(row['body'])
    #    sum_spam_score += spam_score(row)
    #    num_messages += 1
#avg_spam_score = sum_spam_score / num_messages
#for i in range(100000, 100050):
#    print(spam_score(chocobars_chat.iloc(0)[i]))
#    print("\n")
# Out:
# 365 635

# %%
spam_messages
# Out:
# ['VoHiYo',
#  "Make sure to check out Janet's newest video! Youtube.com/watch?v=h1ce_NgBVyY - [PART 8] THE LAST SV VIDEO | XCHOCOBARS STARDEW VALLEY",
#  'POGGERS LIVE',
#  'LIVE POGGERS',
#  'LIVE POGGERS',
#  'chocoWave',
#  'LIVE POGGERS',
#  'live POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'COGGERS',
#  'chocoHug',
#  'LIVE POGGERS',
#  'LIVE POGGERS',
#  'chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave chocoH chocoWave',
#  'chocoWave chocoWave chocoWave chocoWave',
#  'chocoWave',
#  'POGGERS',
#  'chocoWave chocoWave chocoWave chocoWave',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'LIVE POGGERS',
#  'LIVE POGGERS',
#  'chocoWave chocoH',
#  '@xChocoBars chocoWave HI~',
#  'LIVE POGGERS',
#  'chocoWave',
#  'chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave',
#  'chocoWave chocoH',
#  'chocoWave hi janet',
#  'hi janet chocoWave chocoH',
#  'POGGERS',
#  'chocoWave',
#  'training arc POGGERS',
#  'chocoH chocoH chocoWave',
#  'POGGERS',
#  'chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave',
#  'actually live POGGERS',
#  'chocoWave',
#  'chocoWave',
#  'oh live POGGERS',
#  'Solo Squad? POGGERS',
#  'HIIII',
#  'chocoWave hi',
#  'chocoWave',
#  'fuzzycV',
#  'MOM',
#  'POGGERS',
#  'chocoH chocoWave',
#  'i thought was Jebaited',
#  'chocoWave',
#  'how was your day so far chocoHug',
#  'chocoWave',
#  'chocoWave chocoH',
#  'fuzzycV',
#  'HELLO JANIQUA',
#  'POGGERS chocoWave',
#  'chocoWave Hi Janet!',
#  'chocoWave chocoH',
#  'POGGERS',
#  'fuzzycV',
#  'chocoWave POGGERS',
#  'Hi HYPERS',
#  'chocoSip',
#  'POGGERS',
#  'POGGERS LIVE',
#  'MOMMMMMM',
#  'chocoHi',
#  'I LOVE YOU CHOCOOOOO',
#  'LAST OF US',
#  'exciting POGGERS',
#  'PunchTrees',
#  'MOMOMOMOMOMO',
#  'chocoHug chocoHug chocoHug chocoHug',
#  'POGGERS',
#  'TRAINING ARC POGGERS',
#  'POGGERS',
#  'chocoWave',
#  'KonCha KonCha',
#  'POGGERS SENPAI IS LIVE',
#  'Ok',
#  'chocoAww chocoWave chocoAww',
#  'POGGERS',
#  'HURRY UP PEOPLE GET IN HERE POGGERS',
#  'LoveFooty',
#  'FOMEGALULRNITE',
#  'chocoWave',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'MARRY ME DAD <3',
#  'LIVE POGGERS',
#  'chocoWave chocoWave chocoWave',
#  'POGGERS POGGERS',
#  'FAMILY PROJECT POGGERS',
#  'chocoWave',
#  'PROJECT POGGERS',
#  'POGGERS',
#  'chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave chocoWave',
#  'F OMEGALUL RNITE',
#  'POGGERS',
#  'NEW MERCH?',
#  'POGGERS',
#  'chocoWave',
#  'PROJECT POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'YAY POGGERS',
#  'POGGERS',
#  'WITH US? POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'NEW MERCH CONGIRMED Keepo',
#  'MERCH POGGERS',
#  'POGGERS R O J E C T',
#  'POGGERS',
#  'POGGERS',
#  'PREGNANT',
#  'POGGERS POGGERS POGGERS',
#  'STICHES81 COGGERS',
#  'PREGNANT POGGERS',
#  'YAKUZA MERCH POGGERS',
#  'will do dw chocoHug',
#  "Make sure to check out Janet's newest video! Youtube.com/watch?v=h1ce_NgBVyY - [PART 8] THE LAST SV VIDEO | XCHOCOBARS STARDEW VALLEY",
#  'chocoWut',
#  '???',
#  'wait, why does my sub page on twitch say "Renews on Jun 15 (yesterday)" LUL',
#  'chocoWut',
#  'chocoDeaf',
#  'mods? WTF man',
#  'chocoWut',
#  'Vibes: https://goo.gl/gWRhLr - R&S: https://goo.gl/jzSiyJ - Kpop: https://goo.gl/nvZVUT yuzuSC',
#  'alkSuper',
#  'chocoWut',
#  'DOCTOR MERCH Pog',
#  'chocoWave chocoWave chocoWave',
#  'JANET THEMED DOCTOR MERCH POGGERS',
#  'POGGERS',
#  'LUL',
#  'LUL',
#  'POGGERS',
#  'chocoCool',
#  'LUL',
#  'yay janet!!!',
#  'LUL',
#  '@SleepyRobot_ WHEN DID YOU GIFT ME A TOAST SUB chocoThump',
#  'hi everyone!!!!(:',
#  'LUL',
#  'TRAINING COURSE COGGERS',
#  'The heck is going on here in this chat LUL',
#  'LUL',
#  'LUL',
#  'LUL',
#  'chocoCool chocoCool chocoCool',
#  'LUL',
#  'chocoCool chocoCool chocoCool',
#  'workout Keepo',
#  'LUL',
#  'LUL',
#  'chocoCool',
#  'Soylent Kappa',
#  'LUL',
#  'soylent Kappa',
#  'OMEGALUL',
#  'Vitamin Water Kappa',
#  'LUL',
#  'chocoCool chocoCool chocoCool chocoCool',
#  'Soylent POGGERS',
#  'GARY OMEGALUL',
#  'QHAT',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'what POGGERS',
#  'POGGERS',
#  'POGGERS',
#  '@Dong__ :o dumb shit? i am soooo sorry for offending you bud',
#  'POGGERS',
#  'POGGERS',
#  'G FUEL',
#  'POGGERS',
#  'POGGERS',
#  'OMEGALUL',
#  'WTF',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'Soylent LUL',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'SOY MILK POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'CHOCODRINK',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  "@deoxyde At this point I can't keep track LUL. enjoy it",
#  'JANET FUEL',
#  'entrepreneur Janet POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'COGGERS',
#  'TYLER1',
#  'POGGERS',
#  'POGGERS',
#  'CHOCO FUEL',
#  'chocoDRINK',
#  'CHOCO FUEL POGGERS',
#  'J FUEL',
#  'misaglitchPeace',
#  'YAKUZA DRINK POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'POGGERS',
#  'chocoDRINK',
#  'chocoWave chocoWave chocoWave chocoHug chocoHug chocoHug',
#  'chocoSip',
#  'POGGERS',
#  'POGGERS',
#  'CHOCO FUELLLLL',
#  'TearGlove TearGlove TearGlove TearGlove',
#  'CHOCO FUEL POGGERS',
#  'chocoSip',
#  'chocodrink POGGERS',
#  'chocoSip',
#  'Diet Mountain Dew Kappa',
#  'J FUEL OMEGALUL',
#  'chocoSip chocoSip chocoSip',
#  'YAKUZA DRINK POGGERS',
#  'Chocofuel POGGERS',
#  'chocoSip',
#  'WOAH',
#  'chocoSip DRINK',
#  'chocoSip',
#  'Yakuza Gamer Fuel?',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  'POGGERS POGGERS',
#  'OMEGALUL',
#  'chocoSip',
#  'chocoSip',
#  'LUL',
#  'us healthy? LUL',
#  'chocoSip',
#  'chocoLurk',
#  'CHOCO BULL POGCHAMP',
#  'chocoSip',
#  'bar flavour POGGGERS',
#  'C - FUEL',
#  'misaglitchPeace misaglitchGasm',
#  'J FUEL (TM) POGGERS',
#  'POGGERS',
#  'chocoSip',
#  'DIET COKE',
#  'Can i fly??????',
#  'chocoSip',
#  'chocoSip',
#  'chocoSip chocoSip chocoSip',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  'Can I get a discount code? COGGERS',
#  'chocoSip chocoSip chocoSip chocoSip',
#  'chocoSip',
#  'Gatorade Gamer chocoSip',
#  'AS SMART AS STITCHES POGGERS',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  '@xChocoBars WHERE CAN I BUY THAT ASAP',
#  'chocoSip',
#  'chocoSip chocoSip chocoSip chocoSip',
#  'POGGERS LIVE',
#  'chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip chocoSip',
#  'BLOODRUSH MORE LIKE CHOCORUSH LUL',
#  'chocoHYPE',
#  'New monster brand POGGERS',
#  'chocoSip',
#  'Weed Milk Tea',
#  'chocoSip chocoSip chocoSip chocoSip',
#  'VoHiYo VoHiYo VoHiYo',
#  'chocoSip chocoSip chocoSip chocoSip',
#  'Chocolate Milk Kappa',
#  'chocoSip chocoSip chocoSip',
#  'chocoSip chocoSip chocoSip',
#  'kill shroud powers PogChamp',
#  'POGGERS chocoSip',
#  'chocoSip chocoSip chocoSip',
#  'chocoSip',
#  'Yakuza Approved Energy Drink POGGERS',
#  'chocoSip chocoSip chocoSip',
#  'POGGERS',
#  'JFUEL.COM PROMO CODE 4X',
#  'FeelsGoodMan',
#  'chocoWave chocoWave chocoWave chocoWave',
#  'chocoSip chocoSip chocoSip',
#  'chocoSip',
#  'chocoSIp',
#  'chocoSip',
#  '@xChocoBars IM BUYING FULL TRUCK',
#  'GIME DAT',
#  'sallySip',
#  'chocoSip POGGERS chocoSip POGGERS chocoSip POGGERS chocoSip POGGERS chocoSip',
#  'POGGERS',
#  'chocoSip',
#  'YES GOOD IDEA',
#  'chocoSip chocoSip',
#  'YES POGGERS',
#  'ITS COOL POGGERS',
#  "YES I'D BUY POGGERS",
#  'RASPBERRY RASPBERRY',
#  'HELL YEAHHHHHHHHHHH',
#  'toastyB',
#  'chocoSip',
#  'CHOCOLATE',
#  'toastyB',
#  'BON IDEE',
#  'like soylent Kappa',
#  'toastyB toastyB toastyB toastyB',
#  'toastyB',
#  'toastyB flavor',
#  'I LIKE THE IDEA BUT I HAVE NO MONEY',
#  'BERRY',
#  'CHOCOLATE POGGERS',
#  'ORAnge',
#  'toastyB',
#  'LUL Choco Janet, Strawberry Stitches, Jerry Berry....',
#  'RASPBERRY RASPBERRY RASPBERRY RASPBERRY RASPBERRY RASPBERRY RASPBERRY RASPBERRY RASPBERRY',
#  'toast flavour ;)',
#  'CHOCO BERRY',
#  'OMEGALUL',
#  'toastyB of course',
#  'toastyB',
#  'BERRY',
#  'YESSS SIRRRR WE DOOO',
#  'toastyB toastyB toastyB',
#  'chocolate strawberry POGGERS',
#  'MANGO POGGERS',
#  'CRANBERRY',
#  'Mango chocoH',
#  'toastyB',
#  'What LUL',
#  'Orange POGGERS',
#  'DRAGONFRUIT Kreygasm',
#  'mango chocolate Kappa',
#  'YES MANGO POGGERS',
#  'toastyB',
#  'LUL',
#  '@SiRGee562 LUL',
#  'OMEGALUL',
#  'toastyB',
#  'MANGO HELL YEAH',
#  'LUL',
#  'chocoLurk chocoHi',
#  'toastyB this for sure',
#  'LUL',
#  'POGGERS',
#  'chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc chocoThicc',
#  'MANGOOOOO',
#  'JERRY BERRY FLAVORED!',
#  'MANGO POGGERS',
#  '@xChocoBars watermelon chocoHug',
#  'chocoSmart',
#  'toastyB toastyB toastyB toastyB toastyB',
#  'MANGO NATION FeelsGoodMan',
#  'BERRY FTW',
#  'POGGERS',
#  'Berry flavor POGGERS',
#  'chocoH',
#  'Good Luck COGGERS',
#  'chocoWave chocoWave chocoWave',
#  'BERRY POGGERS',
#  'tastes good Kappa',
#  'SPONSOR OFFLINETV AND JUST FRIENDS chocoChamp',
#  'toastyB POGGERS',
#  'toastyB',
#  'grapes chocoSip',
#  'chocoHun',
#  'sugar flavor? chocoG',
#  '@xChocoBars what about watermelon chocoHug',
#  'healthy drink, must taste good #1 priority Kappa',
#  'Health in 2018 LUL Kappa',
#  'VoteYea',
#  'Orange chocoRengar',
#  'creatine flavored. Kappa',
#  'DansGame Green Tea',
#  'apple chocoSip',
#  'chocoHYPE hi chat',
#  'Taro.',
#  'Make a tuna flavor Kappa @xchocobars',
#  'Matcha flavor chocoH',
#  'OOOO GREEN TEA',
#  "Make sure to check out Janet's newest video! Youtube.com/watch?v=h1ce_NgBVyY - [PART 8] THE LAST SV VIDEO | XCHOCOBARS STARDEW VALLEY",
#  '@SiRGee562 prunes?',
#  'IM ON BOARD LEGGO',
#  'YES GREEN TEA',
#  'OHHHH POGGERS GREEN TEA YESSSSS',
#  'toastyB 👈 chocoW',
#  '@FaultyWiresTV chocoW',
#  'PepeHands',
#  '@FaultyWiresTV OMEGALUL',
#  'PepeHands',
#  'PepeHands',
#  'PepeHands',
#  'PepeHands',
#  '@ideologuehs np SeemsGood',
#  'Hi Janet chocoGH',
#  'PepeHands',
#  'PepeHands',
#  'PepeHands',
#  'chocoRE',
#  'PepeHands',
#  'PepeHands',
#  'PepeHands',
#  'prune flavor for old man gary Kappa',
#  'keemstar DansGame',
#  'PepeHands',
#  'PepeHands',
#  'PepeHands',
#  'memestar chocoWut',
#  'PepeHands',
#  'PepeHands',
#  '@XxStarKiller16xX hti me with that creatine chocoFAT',
#  'PepeHands',
#  'put me in your tournament toastyA',
#  'PepeHands',
#  'PepeHands',
#  'KEEMSTAR chocoRE',
#  'Memestar LUL',
#  "don't ask, demand! Kappa",
#  'DEMAND THEM FOR ENTRY toastyA',
#  'chocoG chocoG chocoG chocoG chocoG chocoG chocoG chocoG chocoG chocoG chocoG',
#  'CRANBERRY',
#  'grapes chocoSip',
#  'Taro.',
#  'chocoG',
#  'toastyB toastyB toastyB',
#  'LUL',
#  'CHICKEN',
#  'matcha POGGERS',
#  'alkChoi',
#  'LUL',
#  'LUL',
#  'toastyB',
#  'HeyGuys',
#  'LUL',
#  'LUL',
#  'LMAO',
#  'faulty flavor? PogChamp',
#  'nord mead SwiftRage',
#  'POGGERS meme drink',
#  'A FAULTY DRINK POGGERS',
#  'PEACH',
#  'no faulty flavour chocoKappa',
#  'LOL faulty',
#  'Wtf meme?',
#  'jerry berry flavor toastyB',
#  'FAULTY FLAVOR POGGERS',
#  'Grapes?',
#  'MACHA GREEN TEA OMEGALUL',
#  'faulty flavor? PogChamp',
#  'Lemon chocoSip',
#  'obake2 <3',
#  'Peach?',
#  '@faytlesss YIKES',
#  'LYCHEE',
#  'Red Bean Flavor chocoFAT',
#  'LEMON',
#  'ORANGE @xChocoBars',
#  'Mango for sure chocoG',
#  'Pineapple POGGERS',
#  'Lychee!!!!',
#  'toast-flavoured Kappa',
#  'Orange chocoSip',
#  'Mango pineapple POGGERS',
#  'I was promised a tlou stream chocoTilt',
#  'EVERYONE SPAM chocoH SO IT MOVES UP THE LIST',
#  'Lychee?',
#  'mango watermelon POGGERS',
#  'Chat say chicken!!!!!',
#  '@xChocoBars Pink looks really good on you Janet <3',
#  'chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH chocoH',
#  '@xChocoBars blue berry maybe ? chocoThink',
#  'HOT CHEETOS FLAVOR POGGERS',
#  'strawberry? chocoThink',
#  'YES',
#  'chocoWave chocoWave hi Janet and chat!',
#  "@Haryy you're a memer LUL",
#  'HOT CHEETO DRINK POGGERS',
#  'FLaming hot cheetos FLAVOUR',
#  '@Haryy LUL',
#  'pls not carbonated chocoRNG',
#  'apple chocoRNG',
#  'LUL',
#  'ORANGE!!!!!',
#  'Cheeto flavor LUL',
#  '@Haryy -.-',
#  'I LIKE CARBON',
#  'MHM',
#  'Weed',
#  'cheeto flavor chocoRNG',
#  'LUL both water based',
#  'CARBS ARE BAD',
#  'chocoWave Hi Janet',
#  '@xchocobars No day off??? POGGERS',
#  'WHATS THIS FOR???',
#  '!Prime',
#  'TIER 2? chocoEZ',
#  'chocoWave Whassup guys chocoWave',
#  'chocoEZ',
#  'Hi chat. Hi Janet. chocoWave',
#  'YH U DID',
#  'FeelsBadMan',
#  'chocoH',
#  'chocoH',
#  'chocoHug',
#  'chocoKappa',
#  '<3',
#  'chocoH',
#  'chocoH',
#  'chocoH',
#  'chocoWave chocoWave',
#  'chocoH',
#  'chocoH chocoH chocoH',
#  'chocoH',
#  'chocoH',
#  'chocoH',
#  'LUL',
#  'NO SUGAR, SATIVA INSTEAD LUL',
#  'chocoH',
#  'chocoH chocoH',
#  'chocoH chocoH chocoH',
#  'chocoHun',
#  'chocoH',
#  'POGGERS',
#  'POGGERS VEGAN',
#  "Whats is happening i don't understand BibleThump",
#  '@whitetigerr_ chillll bruh this is brain storming time damn LUL',
#  'organic hfcs Kappa',
#  'NDEXE LMAO',
#  'cyanide chocoRNG',
#  'Kappa',
#  'KappaPride',
#  'peanut butter Kappa',
#  'IS IT GOING TO HAVE GMOs? chocoBruh',
#  '@NDEXE LUL',
#  'LUL',
#  'ambro LUL',
#  'IM VEGAN BUT I EAT MEAT 4Head 4Head',
#  'chocoWave chocoWave chocoWave chocoH chocoH chocoH',
#  '@almightyayo1 hey chocoKappa',
#  'honestly i dont mind calories since sometimes i forget to eat while playing games LUL',
#  '@AceAvenger cmonBruh',
#  'Grape?',
#  'juicy chocoThicc',
#  'just gotta make it so the bottle is 100 servings. low cal LUL',
#  'LIME?',
#  "IF YOUR'E A VEGAN, DRINK WATER",
#  'chocoG chocoG chocoG chocoG',
#  'hello Janet! chocoHug chocoHug chocoHug',
#  "Make sure to check out Janet's newest video! Youtube.com/watch?v=h1ce_NgBVyY - [PART 8] THE LAST SV VIDEO | XCHOCOBARS STARDEW VALLEY",
#  '@xChocoBars blue berry ? chocoHug',
#  'remember when mom was a league streamer LUL',
#  'ORANGE!!!!',
#  'TIME FOR THE WINS EZ',
#  'FLAVORS POGGERS',
#  'chocoS Clap',
#  'SUGARCANE :wear:',
#  'ALL ABOUT DEM FLAVORS POGGERS',
#  'CRANBERRY',
#  'YES',
#  'BANANA POGGERS PLEASE',
#  'Wheres Tricera ops :OOOOOOOO',
#  'TROPICAL POGGERS',
#  '@xChocoBars mango pineapple POGGERS',
#  'Purple flavor LUL',
#  'apple chocoSip',
#  'Blue',
#  'BANANA AND CHOCOLATE',
#  'LIME FLAVOUR',
#  'OUI',
#  'HeinÉ',
#  'DURIAN',
#  'CITRUS!!',
#  'KALE POGGERS chocoKappa',
#  'ORANGE KIWI 😩',
#  'POGGERS',
#  'someone explain please chocoTilt',
#  '@WhiteTigerr_ OMEGALUL',
#  'BANANA AND CHOCOLATE OR STRAWBERRY AND CHOCOLATE',
#  'COTTON CANDY FLAVOR',
#  'DURIAN FLAVOUR',
#  'I JUST JOINED whats this idea about i dont know',
#  'Kappa',
#  'juice flavor Kappa',
#  'Goat',
#  'Durian!!!!',
#  'strawberry kiwi POGGERS',
#  'WATERMELON YOOOO',
#  'Kiwi is good chocoSip',
#  "All these flavors and you haven't added SALT Kappa",
#  '@xChocoBars blue berry chocoH',
#  'tuna flavor Kappa',
#  'coconut!!!!',
#  'WATERMELON',
#  'MANGO',
#  'LIME',
#  '@zyclonex Oh sweet! Thanks chocoH',
#  '@nabertes chocoBruh',
#  'alkChoi alkChoi alkChoi',
#  'CITRUS',
#  '@FourSquares_ Np! chocoH',
#  'HOUSE MILK TEA',
#  'CHICKEN',
#  '@xChocoBars With shaker cup? POGGERS',
#  '@xChocoBars blue berry pls chocoHug',
#  'Duck',
#  'toastyB',
#  'ONLY 1 VOTE',
#  'WATERMELON BOYS',
#  'WHY ARE WE PICKING FLAVORS',
#  'chocoHYPE lets go',
#  'WATERMELON',
#  'only 1???',
#  'chocoHYPE',
#  'Only one vote chocoThump',
#  'POGGERS',
#  'GO LYCHEE SwiftRage',
#  'I want more votes chocoThump',
#  'VoHiYo VoHiYo',
#  'Time to use my VPN chocoC',
#  'IM SO CONFUSED why are we picking flavours!',
#  'POGGERS']

# %%
non_spam_messages
# Out:
# ['hey janet',
#  'solo squading?',
#  'chcooWave',
#  'hi',
#  'What’s goodie',
#  'Hellooooo',
#  'your top looks like an Arizona Ice Tea can',
#  'i thought was Jebait',
#  'Wanna play duos',
#  'HIii janet',
#  'You look pretty today Janet',
#  'looking good',
#  'hi hi hiiii',
#  'You and jerry should do the 2v2 20k tourney next time!',
#  'cheer1000 Bring home a W thanks.',
#  '!prime',
#  'If you are a Twitch Prime user, did you know you get a FREE subscription that you can use on Janet? Want to learn how to get Twitch Prime and what else you get along with it? Click here to find out: https://streamable.com/2j1qw',
#  'hi',
#  'monkaS',
#  'football Pog',
#  'thats adorable',
#  'ddu du ddu du',
#  'stitches81 Pog',
#  "cheer1000 I'll settle for a few K's instead of a W.",
#  'we r family?aAwwwww',
#  'pog',
#  'chocoWave',
#  'pregnant with toast probably',
#  'wth',
#  '!newvid',
#  'wtf',
#  'the fuck is wrong with some of you',
#  'jesus wtf',
#  'wtf chat',
#  'wtf chat',
#  'stop',
#  'Yikes',
#  'wtf chat',
#  'oof',
#  '!social',
#  '♡ https://www.twitter.com/xchocobars ♡ https://www.instagram.com/janetrosee/ ♡ https://www.youtube.com/xchocobarz ♡',
#  'jesus',
#  '!playlist',
#  'ok chat got real offended LOL',
#  'fitnessy lol',
#  ';-; lol wish i was with the potato fam',
#  'PepeHands no energy',
#  "@kevinyiman you're saying dumb shit",
#  'cant wait for that rengar stethoscope',
#  'o',
#  'Tyler1',
#  'Soylent',
#  'im from alaska',
#  "tyler1's blood whatever",
#  'gfuelllll',
#  'potato drink?',
#  'nice Clap',
#  'chocoDrink',
#  'cool',
#  'Choco fuel',
#  'water?',
#  '@FaultyWiresTV Thank you',
#  'hello chat!(((:',
#  'water',
#  '@m6_87 for what?',
#  'xChocoBars are you gonna put in some lean into it?',
#  'McDonald’s is healthy',
#  'its called black coffee',
#  'You can say that.',
#  'guys',
#  'kill shroud power drink lol',
#  'Weed Energy Drink',
#  'just put noodles in it and ill order some',
#  'water flavor',
#  'grape',
#  'what idea',
#  'Get the energy of the yakuza for those long gaming hours',
#  'chocolate',
#  'all of the flavors',
#  'berry',
#  '@xChocoBars berry flavor',
#  'potato flavor',
#  'salt flavor please',
#  'Berry flavor',
#  'Weed flavor',
#  'banocolate',
#  'I want happiness flavour FeelsBadMan',
#  'potato flavour!!',
#  '4HEad flavour',
#  'the less syrup the better',
#  'chocolate and berry flavor LOL',
#  'Berry',
#  'yesss Mango',
#  'what i miss?? what idea???',
#  'pomegranate',
#  'What’s the idea I missed it?',
#  'Jerry Berry',
#  'oooo mango',
#  'cheer100',
#  'Strawberry',
#  'stitches is an entrepreneur',
#  'Mango and maybe Strawberry',
#  'jerry berry',
#  'grape',
#  'it would be cute',
#  'mango is actually so good',
#  'pomegragate and strawberry POGGERS',
#  'wait what is the product again lol',
#  'Mango ftw',
#  '@kirby831 Yakuza Meal Replacement Drink',
#  'vodka flavored @xChocoBars',
#  'honey flavor',
#  'Jerry Berry',
#  'Make sure to always be following the rules of chat! https://goo.gl/PwByFd',
#  'meal replacement drink? yo soylent watch out',
#  'Jerry Berry, Jamet, Tropical Toast',
#  "@xChocoBars if it's an energy drink then fruits sound good, if it's smoothies then the standard choco/vanilla are standard",
#  'It has to be named jerry berry',
#  "Maybe watermelon, since it's easy to make it good heh",
#  '!prime',
#  'If you are a Twitch Prime user, did you know you get a FREE subscription that you can use on Janet? Want to learn how to get Twitch Prime and what else you get along with it? Click here to find out: https://streamable.com/2j1qw',
#  'Choco why dont u ever get invited to fortnite tourneys',
#  'Jerry Berry Strawberry',
#  'matcha Pog',
#  'yes',
#  '!newvid',
#  'russians please rig this election to include a vodka',
#  'banana and mango is my fav',
#  'Why did M666chs get timed out',
#  '@sirgee562 trying to get swole lol',
#  'have a nice stream janet !',
#  '@xChocoBars Maybe a google form so you can get additional feedback?',
#  'jfuel.com/flavors promo code 4x',
#  'Matcha green tree',
#  'Keemstar',
#  'When are u planning on streaming wow again ?',
#  '@FaultyWiresTV for limited emotes, maybe it was not u',
#  'there are too many players/streamers thats why',
#  '@xChocoBars omg you look lovely today',
#  '@ideologuehs ewwww',
#  'PepeHands PepeHands',
#  'heyy Janett',
#  'We spamming him',
#  "@m6_87 yeah i'm not sure how it works",
#  'I know him actually I can ask for you',
#  'do they think you stream too little fortnite?',
#  'Do u want me to ask him for u',
#  '@xChocoBars pomegranate',
#  'Janet could you use a google form to get results and additional feedback?',
#  'chocolate PepeHands',
#  'peach',
#  'Who would you do it with?',
#  'im lost drinks?? what drinks',
#  'peach',
#  'Jerry Berry Strawberry',
#  'Matcha green tea',
#  'What about strawberry ??',
#  'Vanilla Matcha',
#  'i like pomegranate?',
#  '200 solo to get notice??',
#  'pomegranate is not a meme tf',
#  'Faulty Waulty drink??',
#  'wtf',
#  'this is a business, people. no memes allowed',
#  'apple?',
#  'meme flavor names',
#  'I think of you and kiss my pillow before I fall asleep every night.',
#  '@xchocobars why are u so cute?',
#  "what's wrong with pomegranate",
#  'When is Janet gonna play in Friday Fortnite',
#  'is it a milky drink?',
#  'can we have meme names, but legit flavors',
#  'jerry berry or we walk',
#  'pomegranate is great wtf',
#  'Apple could be nice as well',
#  'peach tee',
#  "You're telling people WON'T enjoy the Orange Juice and Toothpaste flavor?",
#  '!uptime',
#  'Apple or iced tea',
#  'Berry everyone loves berry',
#  'No meme flavors? Rip my koast drink',
#  "there's a healthy pomegranate drink in the machine at work and i get it a lot",
#  'Passion fruit',
#  'pomegranate is good tho',
#  'Its a little rare',
#  'pomegranate is a legit juice though ive bought some before at the store',
#  'faulty flavor should taste like tuna',
#  'Peach',
#  'FeelsBadMan pomegranate',
#  'Strawberry',
#  'it should be memo no?cuz like gamers r memers?',
#  '@xChocoBars lime',
#  'how is chocolate not being suggested PepeHands',
#  'water flavor please',
#  'is it more of a juice or milkshake?',
#  "@xChocoBars Is it going to be carbonated? because some flavors don't work if it is",
#  'choco nut',
#  'Hibiscus',
#  'xChocoBars get Pizza flavor',
#  'Faulty flavour should taste like flaming hot cheeetos',
#  'i just love cranberry juice',
#  'strawberry?',
#  'lemon or lychee',
#  'pomegranate + another flavor probably',
#  'strawberry is my favorite',
#  'Classic ones like Strawberry',
#  'Lemonade ?',
#  'why are we listing fruits?',
#  '@Methi4x lol',
#  'Blue berry',
#  'yeah i dont understand why i got timed out i was just saying some flavors lol',
#  'xChocoBars get lettuce sandwich flavor',
#  'Orange',
#  '@xchocobars do you get invited to the Fortnite Friday tournaments?',
#  'chocoH top 30 emote',
#  'strawberry soooooooo',
#  'wait whats happening',
#  'no carbo',
#  'no carbo',
#  'Screen',
#  'xChocoBars or maybe hamburger flavor',
#  'No carbonation',
#  'what is thiss for',
#  '@xChocoBars banana flavor or chocolate?',
#  'yeah no carb is good',
#  'Hello Janet 😊',
#  'mango',
#  'is this a juice? or smoothie?',
#  'meme flavor',
#  'yea is better with out',
#  'shart flavor',
#  'I love my carbonation.',
#  'alcohol or not?',
#  'apple toast flavor',
#  'If you are a Twitch Prime user, did you know you get a FREE subscription that you can use on Janet? Want to learn how to get Twitch Prime and what else you get along with it? Click here to find out: https://streamable.com/2j1qw',
#  "how is everyone's day going!?(:",
#  'how are you gonna make it taste good will it have sugar @xChocoBars',
#  'cinnamon',
#  'carbonation causes osteoporosis',
#  'xChocoBars how much will it cost? Will there be any discounts? Will you sponsor people? Who will you sponsor; how big of a view base? How much will the shipping cost?',
#  'passion fruit!',
#  'Boiled porkchop flavour',
#  'when yall actually go thru with it ill be the test dummy. and also take 50 more xD',
#  'Its ok if you want to take a day off, dont wear yourself out @xChocoBars',
#  "Oh Janet, there are many Fortnite tournaments, you don't really have to join a specific tournament!",
#  'extra msg and aspartame please',
#  'corn syrup monkaS',
#  'monkaS',
#  'vegan would mean no honey',
#  'add sugar so i can get diabetes',
#  'Naked? H-how lewd',
#  'wus happening with the drink suggestions???',
#  '@xChocoBars banana flavor or chocolate?',
#  'mcdonalds flavour is a no then',
#  'NDEXE just asking ya know, I wanna buy it, it seems interesting',
#  '@xChocoBars vegan and honey?',
#  'Banana',
#  'We making a drink?',
#  'both mom and dad examples of good food POGGERS',
#  'is this a smoothie or a juice?',
#  'Barbecue flavor.',
#  '@AceAvenger why ur laughing at me',
#  '♡ https://www.twitter.com/xchocobars ♡ https://www.instagram.com/janetrosee/ ♡ https://www.youtube.com/xchocobarz ♡',
#  'vegan = no honey lol',
#  'Will it be a powdered drink mix or pre packaged? The latter would be a lot more expensive',
#  'this is awesome!',
#  'eating good food',
#  'get the most sugary drink and called it "Liquid Joast"',
#  '!prime',
#  'If you are a Twitch Prime user, did you know you get a FREE subscription that you can use on Janet? Want to learn how to get Twitch Prime and what else you get along with it? Click here to find out: https://streamable.com/2j1qw',
#  '!newvid',
#  'Weaponized Snails flavour',
#  '@xchocobars mixed flavors? Kiwi strawberry and so on',
#  '@xChocoBars orange creamsicle is my flavor suggestion btw!',
#  'Calories are energy we need dem calories',
#  '@xChocoBars the weekly tourny you just sign up at https://umggaming.com/ all the information is on the site',
#  '@xchocobars can u stop being so cute ?',
#  '@xChocoBars have u added grape?',
#  "this is a pretty neat idea. it'll be tough but good luck, hope it works out for you",
#  '😩',
#  'idk whats happening right now',
#  'Grape flavour',
#  'purple',
#  'Straw banana',
#  'i love strawberry banana',
#  'purp drank',
#  'passion fruit!',
#  'i fucking love grape',
#  'lychee',
#  '@xChocoBars vanilla?',
#  '@xChocoBars mt favourite flavour is 14',
#  'Strawberry Banana is always a good combo',
#  'throw a kiwi in there',
#  'pineapple and coconut',
#  '@xChocoBars no troll, i like strawberry, mango, chocolate, pineapple, orange',
#  'Cheese',
#  'Mango pineapple!',
#  'What about Peach Green Tea ?',
#  'What’s she talking about?',
#  'what do you mean calm down, flavours aside this is a great idea, how can we calm down',
#  'Apple black currant',
#  'Pizza flavor',
#  'Wait, what is this for?',
#  'poop flavor',
#  'all the fruit',
#  'just start with like 2 flavors',
#  'durian lmao',
#  '@xChocoBars Passion fruit Flavor',
#  'Apple and Pear',
#  'fourteen flavor',
#  'Durian yuckkk.',
#  'water flavor',
#  'durian is a great fruit but so bad mixed',
#  "@FourSquares_ her and her brother are going to create enery drinks so she's asking for flavors",
#  'Watermelon and grapes',
#  'Pineapple coconut!',
#  'Chicken',
#  'sweaty penis sex flavor',
#  '@xChocoBars Do a Lemon poppy shortbread flavor',
#  'hi',
#  'lychee',
#  '@xChocoBars can you include orange ?',
#  'spaghetti sauce',
#  'fruit punch',
#  'Vanilla Matcha',
#  'coconut VoteNo',
#  'Orange',
#  'Whats going on, I just joined?',
#  'Should have 12 btw flavours',
#  'what is this foor',
#  'Pineapple pen',
#  'for',
#  'pineapple coconut!',
#  '@nabertes your know what that tastes like huh',
#  'the flavour of enemy teams tears',
#  '@xChocoBars Orange creamsicle PepeHands',
#  'https://www.strawpoll.me/15904437',
#  'https://www.strawpoll.me/15904437',
#  'https://www.strawpoll.me/15904437',
#  'The flavor of a well done 130 dollar steak',
#  'https://www.strawpoll.me/15904437',
#  'https://www.strawpoll.me/15904437',
#  'awee',
#  'heyyyy chatttttttttt',
#  '@nabertes shutdown you PC and seek help',
#  'no pineaple coconut',
#  "Uh what's with the fruits?????",
#  '@xChocoBars we can only choose one?',
#  'Pina Colada',
#  'pick lychee you weirdos',
#  'is there only going to be one flavor?',
#  '!command add !flavours pick one flavour https://www.strawpoll.me/15904437',
#  'alrighty',
#  'Toast',
#  'no mango+watermelon FeelsBadMan',
#  "I'm on my android",
#  '!prime',
#  'If you are a Twitch Prime user, did you know you get a FREE subscription that you can use on Janet? Want to learn how to get Twitch Prime and what else you get along with it? Click here to find out: https://streamable.com/2j1qw',
#  '!flavours',
#  'Ooooh raspberry would be good',
#  'Passion fruit is so good',
#  'let the votes commence',
#  'man',
#  'good evening janet!',
#  'oh shit solo squads']
